# %%
import pandas as pd

# %%
df = pd.read_csv('data/stock_percentage_difference.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0  level_0 transaction_date ticker  \
# 0           0        0       2020-03-18   CBRE
# 1           1        1       2020-03-24    CNC
# 2           2        2       2020-03-31     DG
# 3           3        3       2020-02-21    ENV
# 4           4        4       2020-03-17    LKQ
# 5           5        5       2020-02-05   NXST
# 6           6        6       2020-02-24    OKE
# 7           7        7       2020-03-09    OKE
# 8           8        8       2020-03-16    QSR
# 9           9        9       2020-02-25    COO
#
#                                    asset_description          type  \
# 0                CBRE Group Inc Common Stock Class A  sale_partial
# 1                                Centene Corporation      purchase
# 2                         Dollar General Corporation      purchase
# 3                                     Envestnet, Inc  sale_partial
# 4                                    LKQ Corporation  sale_partial
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'level_0', 'transaction_date', 'ticker',
#        'asset_description', 'type', 'amount', 'representative', 'timestamp',
#        'merge_key', 'people', 'state', 'party_x', 'total_senate_years',
#        'total_house_years', 'total_years', 'donation_merge_key', 'name',
#        'total_raised', 'total_from_small_donors', 'percent_from_small_donors*',
#        'total_money_raised', 'party_y', 'start', 'day_30',
#        'day_30_stock_perc_diff', 'day_60', 'day_60_stock_perc_diff', 'day_90',
#        'day_90_stock_perc_diff', 'day_180', 'day_180_stock_perc_diff',
#        'sp_start', 'sp_30', 'sp_30_sp_perc_diff', 'sp_60',
#        'sp_60_sp_perc_diff', 'sp_90', 'sp_90_sp_perc_diff', 'sp_180',
#        'sp_180_sp_perc_diff'],
#       dtype='object')

# %%
df_final = pd.read_csv('data/final_dataset.csv')

# %%
df_final.columns
# Out:
# Index(['Unnamed: 0', 'level_0', 'transaction_date', 'ticker',
#        'asset_description', 'type', 'amount', 'representative', 'timestamp',
#        'merge_key', 'people', 'state', 'party_x', 'total_senate_years',
#        'total_house_years', 'total_years', 'donation_merge_key', 'name',
#        'total_raised', 'total_from_small_donors', 'percent_from_small_donors*',
#        'total_money_raised', 'party_y', 'start', 'day_30', 'day_60', 'day_90',
#        'day_180', 'sp_start', 'sp_30', 'sp_60', 'sp_90', 'sp_180'],
#       dtype='object')

# %%
df_final[['start', 'day_30', 'day_60', 'day_90', 'sp_start', 'sp_30', 'sp_60', 'sp_90']]
# Out:
#             start      day_30      day_60      day_90     sp_start  \
# 0       35.520000   44.500000   39.090000   46.740002  2398.100098
# 1       48.730000   69.239998   64.839996   63.360001  2447.330078
# 2      151.009995  175.300003  191.500000  189.479996  2584.590088
# 3       78.989998   48.860001   55.400002   70.970001  3337.750000
# 4       19.690001   19.840000   23.600000   25.980000  2529.189941
# ...           ...         ...         ...         ...          ...
# 10076   48.080002   48.630001   47.599998   47.730000  1774.199951
# 10077   22.373737   24.553871   23.228115   21.755051  1792.500000
# 10078   54.450001   69.849998   60.389999   58.150002  1790.290039
# 10079   58.400002   63.660000   55.209999   50.759998  1790.290039
# 10080   23.990385   24.298077   24.634615   25.730770  1790.290039
#
#              sp_30        sp_60        sp_90
# 0      2874.560059  2953.909912  3097.739990
# 1      2797.800049  2955.449951  3083.760010
# ...
