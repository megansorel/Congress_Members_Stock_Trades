# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
# get url

for i in range (1, 11):
    url = 'https://www.congress.gov/members?searchResultViewType=compact&pageSize=250&page={}'.format(i)
    res = requests.get(url)
    print(res.status_code)
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
soup = BeautifulSoup(res.content, 'lxml')

# %%
people = []
# senate_years = []
# house_years = []
# party = []
# state = []
#get all members 
for listing in soup.find_all('li', {'class': 'compact'}):
    # get member name under result heading
    for name in listing.find_all('span', {'class': 'result-heading'}):
        people.append(name.text)
    # get all results under div
    for info in listing.find_all('span', {'class': 'result-item'}):
        #get strong and span, filter by strong 
        for strong in info.find_all('strong'):
            if strong.text == 'State:':
                state.append([span.text for span in info.find_all('span')])
            if strong.text == 'Party:':
                party.append([span.text for span in info.find_all('span')])
    for years in listing.find_all('ul', {'class': 'member-served'}:
           # if first string is senate, 
            # inf 
                

            
             

#     print(listing.find_all('ul', {'class': 'member-served'})
# years in senate


# people
# years in house 

# party 

# select id members of house / senate

# get link for senator, go inside and get stuff there
# Out:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# Party:
# Served:
# State:
# District:
# Party:
# Served:
# State:
# District:
# Party:
# Served:

# %%
people
# Out:
# {'Representative Zwach, John M.': 0}
