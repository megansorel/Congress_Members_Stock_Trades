# %%
pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in /opt/anaconda3/lib/python3.8/site-packages (0.18.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import datetime

# %% [markdown]
# # Merging House and Senate Stocks

# %%
house = pd.read_csv('../data/house_stocks.csv')
senate = pd.read_csv('../data/senate_stocks.csv')

# %%
#senate['transaction_date'] = pd.to_datetime(senate['transaction_date'])
senate.drop(columns = ['asset_type', 'comment', 'ptr_link'], inplace=True)
senate['representative'] = senate['senator']
senate.drop(columns = 'senator', inplace = True)
senate.loc[senate['type'] == 'Purchase', 'type'] = 'purchase'
senate.loc[senate['type'] == 'Sale (Full)', 'type'] = 'sale_full'
senate.loc[senate['type'] == 'Sale (Partial)', 'type'] = 'sale_partial'
senate.loc[senate['type'] == 'Exchange', 'type'] = 'exchange'
senate['timestamp'] = [int(datetime.datetime.strptime(timer,"%m/%d/%Y").timestamp()) for 
                       timer in senate['transaction_date']]
senate['transaction_date'] = [str(datetime.datetime.strptime(timer,"%m/%d/%Y"))[:10] for 
                              timer in senate['transaction_date']]

# %%
#house['transaction_date'] = pd.to_datetime(house['transaction_date'])
house.drop(columns = ['disclosure_year', 'disclosure_date', 'district', 
                      'ptr_link', 'cap_gains_over_200_usd'], inplace = True)

house['representative'] = [rep[5:] for rep in house['representative']]
house['timestamp'] = [int(datetime.datetime.strptime(timer,"%Y-%m-%d").timestamp()) for 
                      timer in house['transaction_date']]

# %%
df = pd.concat([house, senate])
df.drop(columns = ['owner'], inplace = True)

# %%
df.dropna(inplace=True)
df.drop(df[df.ticker.str.contains('-')].index, inplace = True)
df.drop(df[df.ticker.str.contains('\.')].index, inplace = True)

# %%
df.to_csv('../data/senate_and_house.csv')

# %% [markdown]
# # Merging member years and main dataframe

# %%
members = pd.read_csv('../data/cleaned_members.csv')

# %%
main = pd.read_csv('../data/senate_and_house.csv')

# %%
members.head()
# Out:
#                people         state       party  total_senate_years  \
# 0        James Abdnor  South Dakota  Republican                   6
# 1    Neil Abercrombie        Hawaii  Democratic                   0
# 2      James Abourezk  South Dakota  Democratic                   6
# 3  Ralph Abraham, Lee     Louisiana  Republican                   0
# 4     Spencer Abraham      Michigan  Republican                   6
#
#    total_house_years  total_years
# 0                  8           14
# 1                 22           22
# 2                  2            8
# 3                  6            6
# 4                  0            6

# %%
main.head()
# Out:
#    Unnamed: 0 transaction_date ticker                    asset_description  \
# 0           4       2020-03-18   CBRE  CBRE Group Inc Common Stock Class A
# 1           5       2020-03-24    CNC                  Centene Corporation
# 2           6       2020-03-31     DG           Dollar General Corporation
# 3          10       2020-02-21    ENV                       Envestnet, Inc
# 4          12       2020-03-17    LKQ                      LKQ Corporation
#
#            type            amount representative   timestamp
# 0  sale_partial  $1,001 - $15,000      Susie Lee  1584504000
# 1      purchase  $1,001 - $15,000      Susie Lee  1585022400
# 2      purchase  $1,001 - $15,000      Susie Lee  1585627200
# 3  sale_partial  $1,001 - $15,000      Susie Lee  1582261200
# 4  sale_partial  $1,001 - $15,000      Susie Lee  1584417600

# %%
# unique in main
names_in_main = main.representative.unique()

# made into a list 
names = []
for name in names_in_main:
    names.append(name)
type(names)

#list of members df 
member_names = []
for name in members.people.values:
    member_names.append(name)

# %%
len(member_names)
# Out:
# 2422

# %%
# unique names in main
keys = {}

for name in names:
    #finding closest math to main data from larger 'members data'
    keys[name] = ((process.extract(name, member_names, limit=2)))

# %%
keys
# Out:
# {'Susie Lee': [('Susie Lee', 100), ('Ralph Abraham, Lee', 86)],
#  'Alan S. Lowenthal': [('Alan Lowenthal, S.', 95), ('Alan Bible', 86)],
#  'Mo Brooks': [('Mo Brooks', 100), ('Jack Brooks, B.', 86)],
#  'Robert J. Wittman': [('Robert Wittman, J.', 95), ('J. Beall', 86)],
#  'Lois Frankel': [('Lois Frankel', 100), ('Al Franken', 73)],
#  'Michael T. McCaul': [('Michael McCaul, T.', 95),
#   ('Michael McNulty, R.', 75)],
#  'Suzan K. DelBene': [('Suzan DelBene, K.', 95), ('John Delaney, K.', 59)],
#  'Greg Gianforte': [('Greg Gianforte', 100), ('Greg Ganske', 72)],
#  'Lloyd K. Smucker': [('Lloyd Smucker', 95), ('Floyd Haskell, K.', 64)],
#  'Earl Blumenauer': [('Earl Blumenauer', 100), ('Earl Hutto', 86)],
#  'James Comer': [('James Comer', 100), ('James Broyhill, T.', 86)],
#  'James R. Langevin': [('James Langevin, R.', 95), ('James Comer', 86)],
#  'Anthony E. Gonzalez': [('Anthony Gonzalez', 95), ('E. Garn', 86)],
#  'Josh Gottheimer': [('Josh Gottheimer', 100), ('Joshua Eilberg', 62)],
#  'Katherine M. Clark': [('Katherine Clark, M.', 95), ('Dick Clark', 86)],
#  'David B. McKinley': [('David McKinley, B.', 95), ('David Davis', 86)],
#  'Nancy Pelosi': [('Nancy Pelosi', 100), ('Nancy Kassebaum, Landon', 86)],
#  'Steve Cohen': [('Steve Cohen', 100), ('Steve Southerland, II', 86)],
#  'Gerald E. Connolly': [('Gerald Connolly, E.', 95), ('Gerald Ford', 86)],
#  'Lloyd Doggett': [('Lloyd Doggett', 100), ('William Scott, Lloyd', 86)],
#  'John Curtis': [('John Curtis, R.', 95), ('John Baldacci, Elias', 86)],
#  'Trey Hollingsworth': [('Trey Hollingsworth', 100), ('Trey Gowdy', 86)],
#  'Kathy Manning': [('Kathy Manning, E.', 95), ('Marvin Leath', 61)],
#  'Sean Patrick Maloney': [('Sean Maloney, Patrick', 95), ('Sean Casten', 86)],
#  'Michael K. Simpson': [('Michael Simpson, K.', 95), ('Alan Simpson, K.', 74)],
#  'Greg Steube': [('W. Steube, Gregory', 86), ('Greg Pence', 67)],
#  'Mark Dr Green': [('Mark Green', 95), ('Al Green', 86)],
#  'Hakeem S. Jeffries': [('Hakeem Jeffries, S.', 95), ('Jim Jeffries', 86)],
#  'Rohit Khanna': [('Ro Khanna', 86), ('Richard Hanna, T.', 64)],
#  'Christopher L. Jacobs': [('L. Bafalis', 86), ('David Boren, L.', 86)],
#  'Billy Long': [('Billy Long', 100), ('Billy Evans, Lee', 86)],
#  'Grace Meng': [('Grace Meng', 100), ('Grace Napolitano, F.', 86)],
#  'eter Meijer': [('Peter Meijer', 96), ('Peter Smith', 64)],
#  'Richard W. Allen': [('Allen Boyd', 86), ('W. Daniel', 86)],
#  'James E Hon Banks': [('Jim Banks', 86), ('James Comer', 86)],
#  'Debbie Dingell': [('Debbie Dingell', 100), ('Debbie Mucarsel-Powell', 86)],
#  'Neal Patrick MD, Facs Dunn': [('Jennifer Dunn', 86), ('Jim Dunn', 86)],
#  'Fred Upton': [('Fred Upton', 100), ('Fred Thompson', 70)],
#  'Doug Lamborn': [('Doug Lamborn', 100), ('Doug Ose', 86)],
#  'Peter J. Visclosky': [('Peter Visclosky, J.', 95), ('Peter Barca', 86)],
#  'George Holding': [('George Holding', 100), ('George Darden, (Buddy)', 86)],
#  'Bob Gibbs': [('Bob Gibbs', 100), ('Bob Livingston', 86)],
#  'Sara Jacobs': [('Sara Jacobs', 100), ('Andrew, Jacobs, Jr.', 86)],
#  'Dwight Evans': [('Dwight Evans', 100), ('Lane Evans', 64)],
#  'Francis Rooney': [('Francis Rooney', 100), ('Rodney Davis', 66)],
#  'Dean Phillips': [('Dean Phillips', 100), ('Dean Heller', 67)],
#  'Peter Welch': [('Peter Welch', 100), ('Peter Dominick, H.', 86)],
#  'Ed Case': [('Ed Case', 100), ('Clifford Case, P.', 86)],
#  'Marie Newman': [('Marie Newman', 100), ('Ann Buerkle, Marie', 86)],
#  'James French Hill': [('J. Hill, French', 87), ('James Comer', 86)],
#  'Gilbert Cisneros': [('Gilbert Cisneros', 100), ('Gilbert Gude', 70)],
#  'K. Michael Conaway': [('K. Conaway, Michael', 95),
#   ('Michael Honda, M.', 71)],
#  'Zoe Lofgren': [('Zoe Lofgren', 100), ('Doug Walgren', 61)],
#  'Brian Mast': [('Brian Mast, J.', 95), ('Brian Bilbray, P.', 86)],
#  'John A. Yarmuth': [('John Yarmuth, A.', 95), ('John Camp', 86)],
#  'Kurt Schrader': [('Kurt Schrader', 100), ('Kim Schrier', 67)],
#  'Neal Patrick MD, FACS Dunn': [('Jennifer Dunn', 86), ('Jim Dunn', 86)],
#  'Mark Green': [('Mark Green', 100), ('Mark Green, E.', 95)],
#  'John Rutherford': [('John Rutherford, H.', 95), ('John Camp', 86)],
#  'James E. Banks': [('Jim Banks', 86), ('Charles Chamberlain, E.', 86)],
#  'Donald Sternoff Beyer': [('Donald Beyer', 86), ('Donald Payne', 86)],
#  'Kevin Hern': [('Kevin Hern', 100), ('Kevin Yoder', 76)],
#  'Tom Malinowski': [('Tom Malinowski', 100), ('Tom Cole', 86)],
#  'Bradley S. Schneider': [('Bradley Schneider, Scott', 89),
#   ('Alma Adams, S.', 86)],
#  'Mike Kelly': [('Mike Kelly', 100), ('Kelly Armstrong', 86)],
#  'Tom Rice': [('Tom Rice', 100), ('Tom Price', 94)],
#  'Susan A. Davis': [('Susan Davis, A.', 95), ('Kathleen Dahlkemper, A.', 86)],
#  'Michael Garcia': [('Michael Fitzpatrick, G.', 86),
#   ('Michael Flanagan, Patrick', 86)],
#  'Virginia Foxx': [('Virginia Foxx', 100), ('Virginia Smith', 72)],
#  'David E. Price': [('David Price, E.', 95), ('Charles Chamberlain, E.', 86)],
#  'Nicholas Van Taylor': [('Van Taylor', 90), ('Van Hilleary', 86)],
#  'Joe Courtney': [('Joe Courtney', 100), ('Joe Baca', 86)],
#  'Mikie Sherrill': [('Mikie Sherrill', 100), ('Katie Hill', 67)],
#  'Debbie Wasserman Schultz': [('Schultz, Wasserman, Debbie', 95),
#   ('Debbie Dingell', 86)],
#  'Ed Perlmutter': [('Ed Perlmutter', 100), ('Ed Case', 86)],
#  'Andrew Garbarino': [('Andrew Garbarino, R.', 95), ('E. Garn', 71)],
#  'Kim Schrier': [('Kim Schrier', 100), ('Jay Kim', 86)],
#  'Charles J. "Chuck" Fleischmann': [('Donald Albosta, J.', 86),
#   ('Alvin Baldus, J.', 86)],
#  'Pete Sessions': [('Pete Sessions', 100), ('Douglas Peterson, (Pete)', 86)],
#  'W. Greg Steube': [('W. Daniel', 86), ('W. Hefner', 86)],
#  'Michael John Gallagher': [('John Adler, H.', 86), ('John Ashcroft', 86)],
#  'Ashley Hinson Arenholz': [('Ashley Hinson', 90), ('Jon Hinson, C.', 86)],
#  'Daniel Crenshaw': [('Dan Crenshaw', 89), ('W. Daniel', 86)],
#  'Garret Graves': [('Garret Graves', 100), ('Sam Graves', 71)],
#  'Deborah K. Ross': [('Deborah Ross, K.', 95), ('Mike Ross', 86)],
#  'Kathy Castor': [('Kathy Castor', 100), ('Troy Carter', 61)],
#  'Michael Patrick Guest': [('Michael Blouin', 86), ('Michael Cloud', 86)],
#  'Robert E. Latta': [('Robert Latta, E.', 95), ('E. Garn', 86)],
#  "Tom O'Halleran": [("Tom O'Halleran", 100), ('Tom Cole', 86)],
#  'David P. Roe': [('David Roe, P.', 95), ('Christopher Carney, P.', 86)],
#  'Neal Patrick Dunn MD, FACS': [('Jennifer Dunn', 86), ('Jim Dunn', 86)],
#  'Adam Kinzinger': [('Adam Kinzinger', 100), ('Pat Danner', 58)],
#  'William R. Timmons': [('William Timmons', 95), ('William Dorn', 86)],
#  'Cheri Bustos': [('Cheri Bustos', 100), ('Cori Bush', 67)],
#  'Kenny Marchant': [('Kenny Marchant', 100), ('Martha Keys, E.', 64)],
#  'Marjorie Taylor Greene': [('Marjorie Greene, Taylor', 95),
#   ('G. Taylor', 86)],
#  'Doris O. Matsui': [('Doris Matsui, O.', 95), ('Robert Matsui, T.', 66)],
#  'Daniel Meuser': [('Daniel Meuser', 100), ('David Marriott, Daniel', 86)],
#  'Scott H. Peters': [('Scott Peters, H.', 95),
#   ('Bradley Schneider, Scott', 86)],
#  'Harley E. Rouda': [('Harley Rouda', 95), ('E. Garn', 86)],
#  'David Trone': [('David Trone, J.', 95), ('David Cicilline, N.', 86)],
#  'Donald Sternoff Honorable Beyer': [('Donald Albosta, J.', 86),
#   ('Donald Bailey, A.', 86)],
#  'Austin Scott': [('Austin Scott', 100), ('C. Franklin, Scott', 86)],
#  'Matt Gaetz': [('Matt Gaetz', 100), ('Matt Cartwright', 86)],
#  'Roger W. Marshall': [('Roger Marshall, W.', 95), ('W. Daniel', 86)],
#  'Judy Chu': [('Judy Chu', 100), ('Judy Biggert', 86)],
#  'Joseph P. Kennedy': [('Joseph Kennedy', 95), ('Joseph Kennedy', 95)],
#  'Susan W. Brooks': [('Susan Brooks, W.', 95), ('Mo Brooks', 86)],
#  'Donna Shalala': [('Donna Shalala, E.', 95), ('Donna Christensen, M.', 86)],
#  'William R. Keating': [('William Keating, R.', 95),
#   ('William Keating, J.', 89)],
#  'Linda T. Sanchez': [('Linda Sanchez, T.', 95), ('Loretta Sanchez', 65)],
#  'David Cheston Rouzer': [('David Davis', 86), ('David Dreier', 86)],
#  'Carol Devine Miller': [('Carol Miller, D.', 87), ('Brad Miller', 86)],
#  'Joseph D. Morelle': [('Joseph Morelle, D.', 95), ('Jon Fox, D.', 86)],
#  'Patrick T. McHenry': [('Patrick McHenry, T.', 95), ('Patrick Meehan', 69)],
#  'Harold Dallas Rogers': [('Harold Ford', 86), ('Harold Rogers', 86)],
#  'David Kustoff': [('David Kustoff', 100), ('David Marriott, Daniel', 86)],
#  'Gus M. Bilirakis': [('Gus Bilirakis, M.', 95), ('Gus Savage', 86)],
#  'Frank Pallone': [('Frank, Pallone, Jr.', 95),
#   ('Frank Stubblefield, A.', 86)],
#  'Bill Pascrell': [('Bill, Pascrell, Jr.', 95), ('Bill Posey', 70)],
#  'Scott Franklin': [('C. Franklin, Scott', 95),
#   ('Bradley Schneider, Scott', 86)],
#  'Victoria Spartz': [('Victoria Spartz', 100), ('Cori Bush', 60)],
#  'cott Franklin': [('C. Franklin, Scott', 86), ('William Franklin, W.', 72)],
#  'Elaine Luria': [('Elaine Luria, G.', 95), ('Madeleine Bordallo, Z.', 60)],
#  'Bill Flores': [('Bill Flores', 100), ('Bill, Chappell, Jr.', 86)],
#  'John B. Larson': [('John Larson, B.', 95), ('John Camp', 86)],
#  'Robert C. "Bobby" Scott': [('Robert Brady, A.', 86), ('Bobby Bright', 86)],
#  'Tim Burchett': [('Tim Burchett', 100), ('Tim Ryan', 86)],
#  'Thomas Massie': [('Thomas Massie', 100), ('Thomas Perriello, S.P.', 86)],
#  'James Hagedorn': [('Jim Hagedorn', 85), ('James Abdnor', 77)],
#  'Justin Amash': [('Justin Amash', 100), ('Juan Vargas', 61)],
#  'Shelley M Capito': [('Shelley Capito, Moore', 88), ('M. Snyder', 86)],
#  'Jerry Moran,': [('Jerry Moran', 100), ('Jerry Costello, F.', 86)],
#  'John Boozman': [('John Boozman', 100), ('John Baldacci, Elias', 86)],
#  'William F Hagerty, Iv': [('William Carney', 86), ('William Dorn', 86)],
#  'Thomas R Carper': [('Thomas Carper, R.', 95), ('Thomas MacArthur', 71)],
#  'Ron L Wyden': [('Ron Wyden', 95), ('William Armstrong, L.', 86)],
#  'Gary C Peters': [('Gary Peters, C.', 95), ('Anthony Beilenson, C.', 86)],
#  'Ladda Tammy Duckworth': [('Tammy Duckworth', 95), ('Tammy Baldwin', 86)],
#  'Daniel S Sullivan': [('W. Daniel', 86), ('Ted Yoho, S.', 86)],
#  'John W Hickenlooper': [('John Hickenlooper, W.', 95), ('John Barrow', 86)],
#  'A. Mitchell Mcconnell, Jr.': [('Jerome Ambro, A.', 86),
#   ('Donald Bailey, A.', 86)],
#  'Patrick J Toomey': [('J. Beall', 86), ('Michael Flanagan, Patrick', 86)],
#  'James M Inhofe': [('James Inhofe, M.', 95),
#   ('Theodore Risenhoover, M.', 86)],
#  'Susan M Collins': [('Susan Collins, M.', 95),
#   ('Theodore Risenhoover, M.', 86)],
#  'Pat Roberts': [('Pat Roberts', 100), ('Ray Roberts', 82)],
#  'Jacklyn S Rosen': [('Jacky Rosen', 85), ('Ronny Jackson', 61)],
#  'William Cassidy': [('Bill Cassidy', 81), ('William Carney', 76)],
#  'Sheldon Whitehouse': [('Sheldon Whitehouse', 100), ('Don Ritter', 63)],
#  'Angus S King, Jr.': [('Angus King', 86), ('Steve King', 86)],
#  'Kelly Loeffler': [('Kelly Loeffler', 100), ('Tom Loeffler', 76)],
#  'Timothy M Kaine': [('Tim Kaine', 86), ('Theodore Risenhoover, M.', 86)],
#  'David A Perdue , Jr': [('David Davis', 86), ('David Dreier', 86)],
#  'Roger F Wicker': [('Roger Wicker, F.', 95), ('Barbara Vucanovich, F.', 86)],
#  'Tina Smith': [('Tina Smith', 100), ('Cindy Hyde-Smith', 86)],
#  'John Hoeven': [('John Hoeven', 100), ('John Baldacci, Elias', 86)],
#  'Roy Blunt': [('Roy Blunt', 100), ('Rochester, Blunt, Lisa', 86)],
#  'John N Kennedy': [('John Kennedy', 95), ('John Camp', 86)],
#  'Rafael E Cruz': [('Charles Chamberlain, E.', 86), ('Ted Cruz', 86)],
#  'Christopher A Coons': [('Christopher Coons, A.', 95), ('A. Ferguson', 86)],
#  'Thomas Udall': [('E. Coleman, Thomas', 86), ('Thomas Eagleton, F.', 86)],
#  'John F Reed': [('John Baldacci, Elias', 86), ('Dewey Bartlett, F.', 86)],
#  'Mark R Warner': [('Mark Warner, R.', 95), ('William Ratchford, R.', 86)],
#  'Thomas R Tillis': [('Thom Tillis', 85), ("Thomas O'Neill", 76)],
#  'Robert P Casey, Jr.': [('Bob Casey', 86), ('Robert Casey', 86)],
#  'Tammy Duckworth': [('Tammy Duckworth', 100), ('Tammy Baldwin', 57)],
#  'Michael F Bennet': [('Michael Bennet, F.', 95),
#   ('Michael Flanagan, Patrick', 86)],
#  'Patty Murray': [('Patty Murray', 100), ('Patrick Murphy', 62)],
#  'Joseph Manchin, Iii': [('Joe, Manchin, III', 89), ('Joseph Biden', 86)],
#  'Chris Van Hollen': [('Hollen, Van, Chris', 95), ('Chris Bell', 86)],
#  'John Cornyn': [('John Cornyn', 100), ('John Baldacci, Elias', 86)],
#  'Maria Cantwell': [('Maria Cantwell', 100), ('Maria Salazar, Elvira', 86)],
#  'Michael  B Enzi': [('Michael Enzi, B.', 95),
#   ('Michael Flanagan, Patrick', 86)],
#  'Benjamin L Cardin': [('Benjamin Cardin, L.', 95), ('L. Bafalis', 86)],
#  'Cory A Booker': [('Cory Booker, A.', 95), ('Christopher Coons, A.', 86)]}

# %%
#where scores live
# for i in range(1, 173):
#     print(keys[i][1][1])

# %%
merge_key = [keys[name][0][0] for name in main['representative']]

# %%
main['merge_key'] = merge_key

# %%
main = main.merge(members, how = 'left', left_on = 'merge_key', right_on='people')

# %%
df = main

# %% [markdown]
# # Merge Donations with Main

# %%
donations = pd.read_csv('../data/congress_donations.csv')
donations['party'] = [name[-2] for name in donations['Name']]
donations.columns = donations.columns.str.lower().str.replace(' ','_')
donations['name'] = [name[:-4] for name in donations['name']]

# %%
df.head()
# Out:
#    Unnamed: 0 transaction_date ticker                    asset_description  \
# 0           4       2020-03-18   CBRE  CBRE Group Inc Common Stock Class A
# 1           5       2020-03-24    CNC                  Centene Corporation
# 2           6       2020-03-31     DG           Dollar General Corporation
# 3          10       2020-02-21    ENV                       Envestnet, Inc
# 4          12       2020-03-17    LKQ                      LKQ Corporation
#
#            type            amount representative   timestamp  merge_key  \
# 0  sale_partial  $1,001 - $15,000      Susie Lee  1584504000  Susie Lee
# 1      purchase  $1,001 - $15,000      Susie Lee  1585022400  Susie Lee
# 2      purchase  $1,001 - $15,000      Susie Lee  1585627200  Susie Lee
# 3  sale_partial  $1,001 - $15,000      Susie Lee  1582261200  Susie Lee
# 4  sale_partial  $1,001 - $15,000      Susie Lee  1584417600  Susie Lee
#
#       people   state       party  total_senate_years  total_house_years  \
# 0  Susie Lee  Nevada  Democratic                   0                  2
# 1  Susie Lee  Nevada  Democratic                   0                  2
# 2  Susie Lee  Nevada  Democratic                   0                  2
# 3  Susie Lee  Nevada  Democratic                   0                  2
# 4  Susie Lee  Nevada  Democratic                   0                  2
#
#    total_years
# 0            2
# 1            2
# 2            2
# 3            2
# 4            2

# %%
donations.head()
# Out:
#                                     name total_raised total_from_small_donors  \
# 0  Ocasio-CortezAlexandria Ocasio-Cortez    $20664795               $16434594
# 1                      TrahanLori Trahan     $1449303                $1151465
# 2                  SandersBernie Sanders    $21565004               $15151822
# 3                 HunterDuncan D. Hunter     $1693623                $1142274
# 4                       JordanJim Jordan    $18313823               $12122206
#
#   percent_from_small_donors* total_money_raised party
# 0                     79.53%  Raised over $100k     D
# 1                     79.45%  Raised over $100k     D
# 2                     70.26%  Raised over $100k     D
# 3                     67.45%  Raised over $100k     R
# 4                     66.19%  Raised over $100k     R

# %%
def clean_name(name):
    first = name.split()[0]
    second = name.split()[1:]
    first_rev = first[::-1]
    for i, let in enumerate(first_rev):
        if let == let.upper():
            index = i
            break
    for word in second:
        if len(word) < 3 or '\.' in word:
            second.remove(word)
    first = first[-(i+1):]
    second.insert(0,first)
    new = ' '.join(second)
    return new

# %%
donations['name'] = [clean_name(name) for name in donations['name']]

# %%
len(donations.name.unique())
# Out:
# 537

# %%
donations.shape
# Out:
# (537, 6)

# %%
len(df.merge_key.unique())
# Out:
# 166

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'transaction_date', 'ticker', 'asset_description', 'type',
#        'amount', 'representative', 'timestamp', 'merge_key', 'people', 'state',
#        'party', 'total_senate_years', 'total_house_years', 'total_years'],
#       dtype='object')

# %%
# get unique list of names in main
names_in_df = df.representative.unique()
# make into a list 
names = []
for name in names_in_df:
    names.append(name)
type(names)
#list of members df 
member_names = []
for name in donations.name.values:
    member_names.append(name)

# %%
keys = {}
for name in names:  #names in smaller dataset to use as merge key
    #finding closest math to main data from larger 'members data'
    keys[name] = ((process.extract(name, member_names, limit=2))) 
    #you can limit to 1 to take less time but I wanted to check

# %%
#checking names that might not match correctly
for name in keys:
    if keys[name][0][1] <= 86:
        print(name, keys[name])
# Out:
# Robert J. Wittman [('J Cox', 86), ('Rob Wittman', 86)]
# James R. Langevin [('James Risch', 86), ('James Comer', 86)]
# Gerald E. Connolly [('Gerry Connolly', 75), ('J Cox', 54)]
# Kathy Manning [('Kay Granger', 58), ('Kathy Castor', 56)]
# Michael K. Simpson [('Mike Simpson', 86), ('Michael Waltz', 66)]
# Rohit Khanna [('Ro Khanna', 86), ('Lori Trahan', 52)]
# Christopher L. Jacobs [('Chris Jacobs', 86), ('Christopher Murphy', 72)]
# eter Meijer [('Peter DeFazio', 58), ('Peter Welch', 55)]
# James E Hon Banks [('James Risch', 86), ('Jim Banks', 86)]
# Neal Patrick MD, Facs Dunn [('Patrick Leahy', 86), ('Neal Dunn', 86)]
# Sara Jacobs [('Chris Jacobs', 70), ('Jose Serrano', 58)]
# Marie Newman [('Madeleine Dean', 62), ('Mike Conaway', 58)]
# Gilbert Cisneros [('Gil Cisneros', 86), ('Bernie Sanders', 60)]
# K. Michael Conaway [('Mike Conaway', 86), ('Michael Waltz', 66)]
# Neal Patrick MD, FACS Dunn [('Patrick Leahy', 86), ('Neal Dunn', 86)]
# James E. Banks [('Jim Banks', 86), ('James Lankford', 64)]
# Donald Sternoff Beyer [('Don Beyer', 86), ('Jon Tester', 63)]
# Bradley S. Schneider [('Bradley Byrne', 86), ('Brad Schneider', 82)]
# Michael Garcia [('Mike Garcia', 80), ('Michael Waltz', 67)]
# Andrew Garbarino [('Andre Carson', 64), ('Andy Harris', 59)]
# Charles J. "Chuck" Fleischmann [('Chuck Grassley', 86), ('J Cox', 86)]
# Pete Sessions [('Pete Olson', 70), ('Pete King', 64)]
# Michael John Gallagher [('Michael Waltz', 86), ('John Cornyn', 86)]
# Ashley Hinson Arenholz [('Dusty Johnson', 56), ('Joe Wilson', 54)]
# Deborah K. Ross [('Ross Spano', 86), ('Ron Estes', 56)]
# Michael Patrick Guest [('Michael Waltz', 86), ('Michael Bennet', 86)]
# David P. Roe [('Phil Roe', 86), ('David Price', 78)]
# Neal Patrick Dunn MD, FACS [('Patrick Leahy', 86), ('Neal Dunn', 86)]
# Marjorie Taylor Greene [('Van Taylor', 86), ('Mark Green', 77)]
# Donald Sternoff Honorable Beyer [('Don Beyer', 86), ('Donald McEachin', 86)]
# Joseph P. Kennedy [('John Kennedy', 76), ('Joe Kennedy III', 69)]
# William R. Keating [('Bill Keating', 86), ('William Timmons', 67)]
# David Cheston Rouzer [('David Perdue', 86), ('David Price', 86)]
# Carol Devine Miller [('Carol Miller', 86), ('Ron Wyden', 60)]
# Harold Dallas Rogers [('Mike Rogers', 86), ('Hal Rogers', 86)]
# Scott Franklin [('Tim Scott', 86), ('Austin Scott', 66)]
# Victoria Spartz [('Brian Schatz', 59), ('Chris Stewart', 57)]
# cott Franklin [('Lois Frankel', 64), ('Ron Kind', 60)]
# Robert C. "Bobby" Scott [('Scott Perry', 86), ('Tim Scott', 86)]
# James Hagedorn [('Jim Hagedorn', 85), ('James McGovern', 71)]
# William F Hagerty, Iv [('William Timmons', 61), ('William Clay Jr.', 61)]
# Thomas R Carper [('Tom Carper', 86), ('Thomas Massie', 64)]
# Daniel S Sullivan [('Dan Sullivan', 83), ('Daniel Lipinski', 62)]
# John W Hickenlooper [('John Cornyn', 86), ('John Carter', 86)]
# A. Mitchell Mcconnell, Jr. [('Mitch McConnell', 86), ('Louis Gohmert Jr.', 86)]
# Patrick J Toomey [('Pat Toomey', 86), ('J Cox', 86)]
# Jacklyn S Rosen [('Jacky Rosen', 85), ('John Rose', 60)]
# William Cassidy [('Bill Cassidy', 81), ('William Clay Jr.', 73)]
# Angus S King, Jr. [('Angus King', 86), ('Pete King', 86)]
# Timothy M Kaine [('Tim Kaine', 86), ('Adrian Smith', 56)]
# David A Perdue , Jr [('David Perdue', 86), ('David Price', 86)]
# Rafael E Cruz [('Ted Cruz', 86), ('Raul Ruiz', 64)]
# Christopher A Coons [('Chris Coons', 86), ('Christopher Murphy', 72)]
# Thomas Udall [('Tom Udall', 86), ('Thomas Massie', 64)]
# John F Reed [('John Kennedy', 70), ('John Rose', 70)]
# Thomas R Tillis [('Thom Tillis', 85), ('Thomas Massie', 60)]
# Robert P Casey, Jr. [('Bob Casey', 86), ('Robert Latta', 86)]
# Joseph Manchin, Iii [('Joe Manchin', 86), ('Joseph Neguse', 60)]
# Michael  B Enzi [('Mike Enzi', 86), ('Michael Bennet', 76)]
# Benjamin L Cardin [('Ben Cardin', 86), ('Jamie Raskin', 55)]

# %%
no_match = ['Michael Enzi', 'Kathy Manning', 'John Hickenlooper', 'William Hagerty', 'cott Franklin', 'Victoria Spartz',
           'Marjorie Taylor Greene', 'Marie Newman', 'eter Meijer', 'David Cheston Rouzer', 'Robert "Bobby" Scott']

second_match = ['Mitchell Mcconnell, Jr.', 'Harold Dallas Rogers', 'Neal Patrick Dunn MD, FACS']

# %%
keys[name][1][0]
# Out:
# 'Cory Gardner'

# %%
donation_merge_key = [keys[name][1][0] if
                      name in second_match \
                      else None if name in no_match else
                      keys[name][0][0] for name in main['representative']]

# %%
donation_merge_key
# Out:
# ['Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Mo Brooks',
#  'Mo Brooks',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'J Cox',
#  'J Cox',
#  'J Cox',
#  'J Cox',
#  'J Cox',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Michael McCaul',
#  'Suzan DelBene',
#  'Suzan DelBene',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Lloyd Smucker',
#  'Earl Blumenauer',
#  'James Comer',
#  'James Comer',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'James Risch',
#  'Anthony Gonzalez',
#  'Anthony Gonzalez',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Lois Frankel',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Katherine Clark',
#  'Katherine Clark',
#  'Katherine Clark',
#  'Katherine Clark',
#  'Katherine Clark',
#  'Katherine Clark',
#  'Katherine Clark',
#  'Katherine Clark',
#  'Katherine Clark',
#  'Katherine Clark',
#  'Katherine Clark',
#  'Katherine Clark',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'David McKinley',
#  'David McKinley',
#  'David McKinley',
#  'David McKinley',
#  'David McKinley',
#  'David McKinley',
#  'David McKinley',
#  'David McKinley',
#  'David McKinley',
#  'David McKinley',
#  'David McKinley',
#  'David McKinley',
#  'David McKinley',
#  'David McKinley',
#  'David McKinley',
#  'David McKinley',
#  'David McKinley',
#  'David McKinley',
#  'David McKinley',
#  'Nancy Pelosi',
#  'Steve Cohen',
#  'Steve Cohen',
#  'Steve Cohen',
#  'Steve Cohen',
#  'Steve Cohen',
#  'Gerry Connolly',
#  'Lloyd Doggett',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'Trey Hollingsworth',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Anthony Gonzalez',
#  'Sean Patrick Maloney',
#  'Sean Patrick Maloney',
#  'Sean Patrick Maloney',
#  'Sean Patrick Maloney',
#  'Sean Patrick Maloney',
#  'Sean Patrick Maloney',
#  'Sean Patrick Maloney',
#  'Sean Patrick Maloney',
#  'Mike Simpson',
#  'Greg Steube',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Earl Blumenauer',
#  'Earl Blumenauer',
#  'Earl Blumenauer',
#  'Mark Green',
#  'Mark Green',
#  'Mark Green',
#  'Mark Green',
#  'Mark Green',
#  'Mark Green',
#  'Mark Green',
#  'Mark Green',
#  'Mark Green',
#  'Mark Green',
#  'Mark Green',
#  'Mark Green',
#  'Mark Green',
#  'Mark Green',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'Greg Gianforte',
#  'J Cox',
#  'Hakeem Jeffries',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Ro Khanna',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Billy Long',
#  'Billy Long',
#  'Billy Long',
#  'Billy Long',
#  'Billy Long',
#  'Billy Long',
#  'Billy Long',
#  'Billy Long',
#  'Billy Long',
#  'Billy Long',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'Lloyd Doggett',
#  'Lloyd Doggett',
#  'Lloyd Doggett',
#  'Lloyd Doggett',
#  'Grace Meng',
#  'James Risch',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Richard Allen',
#  'James Risch',
#  'Suzan DelBene',
#  'Debbie Dingell',
#  'Debbie Dingell',
#  'Mike Simpson',
#  'Mo Brooks',
#  'Mo Brooks',
#  'Mo Brooks',
#  'Mo Brooks',
#  'Mo Brooks',
#  'Mo Brooks',
#  'Mo Brooks',
#  'Mo Brooks',
#  'Patrick Leahy',
#  'Patrick Leahy',
#  'Patrick Leahy',
#  'Patrick Leahy',
#  'James Comer',
#  'James Comer',
#  'James Comer',
#  'James Comer',
#  'James Comer',
#  'James Comer',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'John Curtis',
#  'Lloyd Doggett',
#  'Lloyd Doggett',
#  'Lloyd Doggett',
#  'Fred Upton',
#  'Gerry Connolly',
#  'Douglas Lamborn',
#  'Douglas Lamborn',
#  'Douglas Lamborn',
#  'Douglas Lamborn',
#  'Douglas Lamborn',
#  'Douglas Lamborn',
#  'Pete Visclosky',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Earl Blumenauer',
#  'Earl Blumenauer',
#  'Lloyd Doggett',
#  'George Holding',
#  'George Holding',
#  'George Holding',
#  'George Holding',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Bob Gibbs',
#  'Bob Gibbs',
#  'Bob Gibbs',
#  'Bob Gibbs',
#  'Bob Gibbs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Chris Jacobs',
#  'Dwight Evans',
#  'Dwight Evans',
#  'Dwight Evans',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Josh Gottheimer',
#  'Francis Rooney',
#  'Francis Rooney',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Peter Welch',
#  'Peter Welch',
#  'Peter Welch',
#  'Peter Welch',
#  'Peter Welch',
#  'Earl Blumenauer',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Susie Lee',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Dean Phillips',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Alan Lowenthal',
#  'Hakeem Jeffries',
#  'Richard Allen',
#  'Ed Case',
#  'Ed Case',
#  'Ed Case',
#  'Ed Case',
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  'Suzan DelBene',
#  'French Hill',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  'Gil Cisneros',
#  ...]

# %%
df['donation_merge_key'] = donation_merge_key

# %%
df.head()
# Out:
#    Unnamed: 0 transaction_date ticker                    asset_description  \
# 0           4       2020-03-18   CBRE  CBRE Group Inc Common Stock Class A
# 1           5       2020-03-24    CNC                  Centene Corporation
# 2           6       2020-03-31     DG           Dollar General Corporation
# 3          10       2020-02-21    ENV                       Envestnet, Inc
# 4          12       2020-03-17    LKQ                      LKQ Corporation
#
#            type            amount representative   timestamp  merge_key  \
# 0  sale_partial  $1,001 - $15,000      Susie Lee  1584504000  Susie Lee
# 1      purchase  $1,001 - $15,000      Susie Lee  1585022400  Susie Lee
# 2      purchase  $1,001 - $15,000      Susie Lee  1585627200  Susie Lee
# 3  sale_partial  $1,001 - $15,000      Susie Lee  1582261200  Susie Lee
# 4  sale_partial  $1,001 - $15,000      Susie Lee  1584417600  Susie Lee
#
#       people   state       party  total_senate_years  total_house_years  \
# 0  Susie Lee  Nevada  Democratic                   0                  2
# 1  Susie Lee  Nevada  Democratic                   0                  2
# 2  Susie Lee  Nevada  Democratic                   0                  2
# 3  Susie Lee  Nevada  Democratic                   0                  2
# 4  Susie Lee  Nevada  Democratic                   0                  2
#
#    total_years donation_merge_key
# 0            2          Susie Lee
# 1            2          Susie Lee
# 2            2          Susie Lee
# 3            2          Susie Lee
# 4            2          Susie Lee

# %%
df = df.merge(donations, how = 'left', left_on = 'donation_merge_key', right_on='name')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'transaction_date', 'ticker', 'asset_description', 'type',
#        'amount', 'representative', 'timestamp', 'merge_key', 'people', 'state',
#        'party_x', 'total_senate_years', 'total_house_years', 'total_years',
#        'donation_merge_key', 'name', 'total_raised', 'total_from_small_donors',
#        'percent_from_small_donors*', 'total_money_raised', 'party_y'],
#       dtype='object')

# %%
df.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
df.columns
# Out:
# Index(['transaction_date', 'ticker', 'asset_description', 'type', 'amount',
#        'representative', 'timestamp', 'merge_key', 'people', 'state',
#        'party_x', 'total_senate_years', 'total_house_years', 'total_years',
#        'donation_merge_key', 'name', 'total_raised', 'total_from_small_donors',
#        'percent_from_small_donors*', 'total_money_raised', 'party_y'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# transaction_date                0
# ticker                          0
# asset_description               0
# type                            0
# amount                          0
# representative                  0
# timestamp                       0
# merge_key                       0
# people                          0
# state                           0
# party_x                         0
# total_senate_years              0
# total_house_years               0
# total_years                     0
# donation_merge_key            448
# name                          448
# total_raised                  448
# total_from_small_donors       448
# percent_from_small_donors*    448
# total_money_raised            448
# party_y                       448
# dtype: int64

# %%
df.to_csv('../data/house_senate_years_donations.csv', index = False)
